# %%
import dlib
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../multi-faces.jpg',)
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(img,2)
detections
# Out:
# rectangles[[(223, 124) (241, 142)], [(516, 99) (537, 120)], [(264, 108) (285, 130)], [(422, 116) (444, 137)], [(69, 101) (91, 123)], [(243, 112) (261, 130)], [(365, 114) (383, 132)], [(331, 112) (349, 130)], [(447, 106) (465, 124)], [(147, 112) (165, 130)], [(305, 126) (323, 144)], [(395, 104) (413, 122)], [(181, 120) (199, 138)], [(115, 116) (133, 134)], [(199, 114) (217, 132)], [(285, 108) (303, 126)], [(472, 113) (494, 135)], [(93, 96) (115, 118)]]

# %%
for face in detections:
    cv2.rectangle(img,(face.left(),face.top()),(face.right(),face.bottom()),(255,0,255),2)

plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
